# %% [markdown]
# # Plots the United States
#
# It is always convenient to be able to plots states.  Let's boogie on dat.

# %%
# %load_ext importable
from toolz.curried import *; from pandas import *; import pandas as pd
# Out:
# The importable extension is already loaded. To reload it, use:
#   %reload_ext importable

# %% [markdown]
# ## [Shape files from census.gov](https://www.census.gov/geo/maps-data/data/cbf/cbf_state.html)
#
# ## [`@aerispaha1`s gist to read shapefiles to a dataframe](https://gist.github.com/aerispaha/f098916ac041c286ae92d037ba5c37ba)
#
# Load that file in with the `%load` magic.

# %%
# %load https://gist.githubusercontent.com/aerispaha/f098916ac041c286ae92d037ba5c37ba/raw/bbec58b3e39ee709e5e96aa65e87e6b568ab4a84/read_shapefile.py
def read_shapefile(shp_path):
	"""
	Read a shapefile into a Pandas dataframe with a 'coords' column holding
	the geometry information. This uses the pyshp package
	"""
	import shapefile

	#read file, parse out the records and shapes
	sf = shapefile.Reader(shp_path)
	fields = [x[0] for x in sf.fields][1:]
	records = sf.records()
	shps = [s.points for s in sf.shapes()]

	#write into a dataframe
	df = pd.DataFrame(columns=fields, data=records)
	df = df.assign(coords=shps)

	return df

# %%
from sklearn import preprocessing
from bokeh.plotting import *; from bokeh.models import *
output_notebook(resources=__import__('bokeh').resources.CDN)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5c3fdc25-bbf8-45ff-961a-328846f4ec92">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# * Read the shapefile after unzipping the contents from census.gov

# %%
df = read_shapefile('../../../Downloads/cb_2016_us_state_500k/cb_2016_us_state_500k.shp')

# nth controls the density of edge points.
nth = 15

df = concat([
    df, concat(dict(
        x=df.coords.apply(compose(list, take_nth(nth), pluck(0))),
        y=df.coords.apply(compose(list, take_nth(nth), pluck(1)))
    ), axis=1)], axis=1).set_index('NAME')

for _ in 'xy': df[_] = df[_].apply(preprocessing.minmax_scale, args=[[-.5, .5]])

# %%
source = df[list('xy')].pipe(ColumnDataSource)

# %%
p = figure()
for i in range(50):
    p.patches(
        dict(
            field='x',
            transform=CustomJSTransform(v_func="""return xs.map(function(v, i){
                return v.map(function(w){return w+%i});
            });"""%i)
        ),
        dict(
            field='y', 
            transform=CustomJSTransform(
                v_func="""return xs.map(function(v, i){
                return v.map(function(w){return (w+i+%i) %s 50 });
            });"""%(i, '%'))
        ), fill_alpha=0, source=source)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8a883f9a-4dad-45e9-b737-a95e67db9f13"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("8a883f9a-4dad-45e9-b737-a95e67db9f13");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8a883f9a-4dad-45e9-b737-a95e67db9f13");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8a883f9a-4dad-45e9-b737-a95e67db9f13' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6e006e36-4659-47ff-80e9-11a8a0d4ef72":{"roots":{"references":[{"attributes":{"source":{"id":"a6eb0943-35f8-44e8-a50c-f9123692f4b2","type":"ColumnDataSource"}},"id":"7ba63b62-842f-46dd-9013-8d7a7f0f501f","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"f1084a6f-c8b6-471f-9b11-8039a13ed973","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"0eee5615-1462-4e3d-8a59-6c60300d5e63","type":"CustomJSTransform"}}},"id":"bb7fd4c7-f9fa-442b-937b-f732a3bd14aa","type":"Patches"},{"attributes":{"v_func":"return xs.map(function(v, i){\n                return v.map(function(w){return (w+i+33) % 50 });\n            });"},"id":"2ec31abd-78d7-439c-9d1e-400f9d8e5966","type":"CustomJSTransform"},{"attributes":{"fill_alpha":{"value":0},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"f1084a6f-c8b6-471f-9b11-8039a13ed973","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"0eee5615-1462-4e3d-8a59-6c60300d5e63","type":"CustomJSTransform"}}},"id":"1c9fb66e-aa99-411a-a0d8-fdf2d72280a2","type":"Patches"},{"attributes":{"data_source":{"id":"a6eb0943-35f8-44e8-a50c-f9123692f4b2","type":"ColumnDataSource"},"glyph":{"id":"2eb21411-624d-4f0c-a359-174b7e294ab2","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"549cba13-a755-4c1a-800b-24dcfab2a371","type":"Patches"},"selection_glyph":null,"view":{"id":"e1af0ad8-c3d1-4235-8488-a71cfeebd297","type":"CDSView"}},"id":"73b01d48-094b-4ec9-b334-38a002ca8cd0","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"44598615-f04f-4423-bb93-6bfa652f4e42","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"29d30050-9040-40e9-b71e-5d63a0aa2a60","type":"CustomJSTransform"}}},"id":"549cba13-a755-4c1a-800b-24dcfab2a371","type":"Patches"},{"attributes":{"v_func":"return xs.map(function(v, i){\n                return v.map(function(w){return (w+i+29) % 50 });\n            });"},"id":"78c46660-d23d-47c1-9353-930ac5f17e13","type":"CustomJSTransform"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"a3a80e83-2337-4ba1-adbf-f0ac51d49fdd","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"2ec31abd-78d7-439c-9d1e-400f9d8e5966","type":"CustomJSTransform"}}},"id":"c2a2b1a7-be88-45fd-bcba-55642122f5d6","type":"Patches"},{"attributes":{},"id":"c37a48de-6d4d-4e60-b660-79b70e0bd4f9","type":"BasicTicker"},{"attributes":{"v_func":"return xs.map(function(v, i){\n                return v.map(function(w){return w+22});\n            });"},"id":"5c6acbed-a725-4fdf-a13b-f7c8482abf39","type":"CustomJSTransform"},{"attributes":{"fill_alpha":{"value":0},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"d2e0663c-b589-4dc1-b87c-5c4e46af52f8","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"f1c4086b-e832-4581-8a31-ac29f4619a37","type":"CustomJSTransform"}}},"id":"71505ad7-0590-4423-b355-de6bcc645c0b","type":"Patches"},{"attributes":{"v_func":"return xs.map(function(v, i){\n                return v.map(function(w){return (w+i+9) % 50 });\n            });"},"id":"f02a44c1-29a0-4496-9a04-fe7ecf863f80","type":"CustomJSTransform"},{"attributes":{"v_func":"return xs.map(function(v, i){\n                return v.map(function(w){return (w+i+37) % 50 });\n            });"},"id":"a8e54f92-4793-4f6b-bbaa-d28d339a4cd2","type":"CustomJSTransform"},{"attributes":{"source":{"id":"a6eb0943-35f8-44e8-a50c-f9123692f4b2","type":"ColumnDataSource"}},"id":"fe1c71a2-471c-403e-b106-f7c1672a33aa","type":"CDSView"},{"attributes":{},"id":"7a ...

# %%
p = figure()
for i in range(50):
    p.patches(
        dict(
            field='x',
            transform=CustomJSTransform(v_func="""return xs.map(function(v, i){
                return v.map(function(w){return w+%i});
            });"""%i)
        ),
        dict(
            field='y', 
            transform=CustomJSTransform(
                v_func="""return xs.map(function(v, i){
                return v.map(function(w){return (w+i+%i) %s 50 });
            });"""%(i*0, '%'))
        ), fill_alpha=0, source=source)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bf19f21d-d89a-499e-9e4f-f4a9b70accaf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("bf19f21d-d89a-499e-9e4f-f4a9b70accaf");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bf19f21d-d89a-499e-9e4f-f4a9b70accaf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bf19f21d-d89a-499e-9e4f-f4a9b70accaf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"48ba9049-542b-4dc1-bd8d-aeff3d918b7a":{"roots":{"references":[{"attributes":{},"id":"11a39d60-27dd-45da-8ef6-357faa7dab53","type":"BasicTicker"},{"attributes":{"source":{"id":"a6eb0943-35f8-44e8-a50c-f9123692f4b2","type":"ColumnDataSource"}},"id":"5b010ab7-5a5c-4351-a244-e196873f9b19","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"29410095-9b86-4c6a-bb32-58809fb21b6e","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"9c57ae86-a9ce-4d07-8779-eb1c0155a86c","type":"CustomJSTransform"}}},"id":"e790caac-e5e2-4002-a1e0-9bbfc5d60a24","type":"Patches"},{"attributes":{"source":{"id":"a6eb0943-35f8-44e8-a50c-f9123692f4b2","type":"ColumnDataSource"}},"id":"97a86805-1c16-40ff-949b-c1270df80c5b","type":"CDSView"},{"attributes":{"data_source":{"id":"a6eb0943-35f8-44e8-a50c-f9123692f4b2","type":"ColumnDataSource"},"glyph":{"id":"88ce629d-d181-409d-b75a-d7ea292bd32a","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1d3d5e33-9d3d-4a0f-b257-2b0859f2ae31","type":"Patches"},"selection_glyph":null,"view":{"id":"5b010ab7-5a5c-4351-a244-e196873f9b19","type":"CDSView"}},"id":"187a90c6-bbb2-471b-99d1-a650420aa579","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"be71f55a-8a40-4752-98ed-e3ee94836542","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"39c3d973-f320-469c-a7fa-f36cc56561d2","type":"CustomJSTransform"}}},"id":"7c1dc0c7-6d89-4589-bba2-a4b6abb8ff73","type":"Patches"},{"attributes":{"v_func":"return xs.map(function(v, i){\n                return v.map(function(w){return w+29});\n            });"},"id":"6d2ac099-b4ae-453a-ae88-beefa1f52afa","type":"CustomJSTransform"},{"attributes":{"source":{"id":"a6eb0943-35f8-44e8-a50c-f9123692f4b2","type":"ColumnDataSource"}},"id":"557b8a85-88e9-45a7-82ca-1f7c2ca2ad00","type":"CDSView"},{"attributes":{},"id":"ab9c3a5a-5932-465f-a9d5-e7a224278c22","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"472a5b9e-b385-459b-808f-48cfeab80ee9","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"cf7aae31-ce5a-4bdf-b50a-2dc4b7301ff0","type":"CustomJSTransform"}}},"id":"2ea1e0a2-879d-4378-b1d5-e71758e93401","type":"Patches"},{"attributes":{"v_func":"return xs.map(function(v, i){\n                return v.map(function(w){return w+11});\n            });"},"id":"b30c10d0-f87f-4344-aa2f-7e3254e17bbd","type":"CustomJSTransform"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"b253baf2-aa33-41b5-b2ee-41eced81500f","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"ccb5fa94-482c-4dc1-b5cd-00eb7cf938d4","type":"CustomJSTransform"}}},"id":"3d74a910-c6a0-4db2-993e-fe8e084ad515","type":"Patches"},{"attributes":{"data_source":{"id":"a6eb0943-35f8-44e8-a50c-f9123692f4b2","type":"ColumnDataSource"},"glyph":{"id":"493166b8-fc34-47bd-bede-a881f167f411","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ec812525-f828-4e21-abe8-fb56c402cbfa","type":"Patches"},"selection_glyph":null,"view":{"id":"2ddaa3d6-22b1-496e-b3b0-de46186e6d3d","type":"CDSView"}},"id":"93d81097-34ed-4209-81b1-b4694a9fe704","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"xs":{"field":"x","transform":{"id":"8926bcf7-a09c-4e96-81a0-99775a8ccc82","type":"CustomJSTransform"}},"ys":{"field":"y","transform":{"id":"7afde868-a9ca-4a60-b465-64fb1229a777","type":"CustomJSTransform"}}},"id":"61564419-f2a7-43ea-8610-f1f286afca5c","type":"Patches"},{"at ...

# %% [markdown]
# > Consider making a package that has each patch easily available with the correct transforms.
